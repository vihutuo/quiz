# %%
import openai
from IPython.display import clear_output
from time import sleep

QuestionCategories_old = [
                        {"name":"SQL","keyword":"SQL","total":2},
                        {"name":"Computer Networks","keyword":"Computer Networks","total":2},
                        {"name":"Python Functions","keyword":"Python Functions","total":6},
                        {"name":"Python Output","keyword":"Python Output","total":6},

                        {"name":"Python data types","keyword":"Python data types","total":6},
                        {"name":"Parity Check","keyword":"Simple parity check","total":6},
                     ]


QuestionCategories = [
                        {"name":"Python operators","keyword":"Python operators","total":6},
                    
                     ]
All_Questions=[]

api_key="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"
def FetchQuestions():
    all_my_questions=[]
    for c in  QuestionCategories:
        questions=GetQuestions(c["keyword"],c["total"])
        all_my_questions.append(questions)
        sleep(5)
    return all_my_questions    
    
def GetQuestions(topic,number=1):
        # Set up the OpenAI API client
        openai.api_key = api_key

        # Set up the model and prompt
        model_engine = "text-davinci-003"
        #model_engine = "text-curie-001"
        #prompt = f"""
        #Give me an MCQ on {topic} with answer and explanation. Give 4 choices numbered from 1 to 4. 
        #Provide answer as a single number from 1 to 4 with absolutely no text.
        #Separate the question,each choice,answer and explanation with the character ||.

        #"""
        prompt = f"""
        Give me an MCQ on {topic} with answer and explanation in the following format. Use || as delimiter.
        Make sure the answer is always numeric even if the choices has numbers.
        Question||1. Choice 1||2. Choice 2 ||3. Choice 3 ||4. Choice 4 || Answer:2 ||Explanation

        """

        # Generate a response
        completion = openai.Completion.create(
            engine=model_engine,
            prompt=prompt,
            max_tokens=1024,
            n=number,
            stop=None,
            temperature=0.5,
        )

        #print(completion)
        #response = completion.choices[0].text
        questions_list=[]
        for x in completion.choices:
            print(x.text)
            question={}
            L1=x.text.split("||")
            question["q"]= L1[0]
            question["choice1"] = L1[1]
            question["choice2"] = L1[2]
            question["choice3"] = L1[3]
            question["choice4"] = L1[4]
            answer=str(L1[5])
            answer=answer.replace("Answer:","")
            #answer=answer.replace(".","")
            #answer=answer.replace(":","")
            
            print("Answer:",answer)
            question["answer"] = int(answer)
            question["explanation"] = L1[6]
            question["topic"] = topic
            
            #print(x.text)
            questions_list.append(question)
        return questions_list    


            
        
All_Questions=FetchQuestions()
print("Fetched")
# Out:
# What is the output of the following code?
#
# a = 5
# b = 10
# print(a + b)||1. 15 ||2. 10 ||3. 5 ||4. Error ||Answer:1 ||Explanation: The output of the code is 15, as the + operator is used to add two numbers, a and b.
# Answer: 1
#
# Q. What is the output of the following code?
#
# print(5 + 5 * 5) ||1. 25 ||2. 50 ||3. 55 ||4. 75 ||Answer:3 ||Explanation: The order of operations in Python is Parentheses, Exponents, Multiplication, Division, Addition, Subtraction (PEMDAS). The expression 5 + 5 * 5 is evaluated as 5 + (5 * 5) which is 55.
# Answer: 3
#
# Q. What is the output of the following code?
# `print(2 + 3 * 4)`||1. 14 ||2. 20 ||3. 22 ||4. 24 ||Answer:2 ||Explanation: The output of the expression is 20 since multiplication operator has higher precedence than the addition operator.
# Answer: 2
#
# ...

# %%
import copy

def PrintMenu(all_questions):
   
        print("Select a category for your question : ")
        i = 1
        for c in  QuestionCategories:
            print(i,".",c["name"],len(all_questions[i-1]),   flush=True)
            i+=1
        print("0. Exit",flush=True)    

        r=int(input("Enter your choice : "))
        return r
def main():
    global All_Questions
    all_questions = copy.deepcopy(All_Questions)
   # all_questions=FetchQuestions()
    #print("All Questions:",all_questions)
    choice=1
    while choice != 0:
        clear_output(wait=True)
        #sleep(1)
        choice=PrintMenu(all_questions)
        if choice == 0:
            break
       
        #topic= QuestionCategories[choice-1]["keyword"]
        #print(topic, "Fetching question from ChatGPT...")
        #question=GetQuestion(topic)
        clear_output(wait=True)
        topic_index=choice-1
        if len(all_questions[topic_index])<=0:
            print("No more question in this topic")
            pass
            input("Press any key to continue")
            continue
                
        question=all_questions[topic_index][0]
        print(question["q"],"\n")
        print(question["choice1"])
        print(question["choice2"])
        print(question["choice3"])
        print(question["choice4"])
        pass
        user_answer = int(input("Enter answer (1-4) :"))
        if user_answer == question["answer"]:
            print("Correct")
        else:
           print("Incorrect")
           print("Correct answer is",question["answer"]) 
        print(question["explanation"])
        all_questions[topic_index].pop(0)
        input("Press any key to continue")      

main()
# Out:
# Select a category for your question :
# 1 . Python Functions 3
# 0. Exit
# Enter your choice : 0

# %%
print(All_Questions)
# Out:
# [[], [], []]

# %%
import openai
from IPython.display import clear_output
from time import sleep

QuestionCategories = [
                        {"name":"SQL","keyword":"SQL"},
                        {"name":"Python output","keyword":"Python output"},
                     ]

api_key="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"


def GetQuestion(topic):
        # Set up the OpenAI API client
        openai.api_key = api_key

        # Set up the model and prompt
        model_engine = "text-davinci-003"
        prompt = f"""
        Give me an MCQ on {topic} with answer and explanation in the following format. Use || as delimiter.
        Make sure the answer is always numeric even if the choices has numbers.
        Question||1. Choice 1||2. Choice 2 ||3. Choice 3 ||4. Choice 4 || Answer:2 ||Explanation

        """

        # Generate a response
        completion = openai.Completion.create(
            engine=model_engine,
            prompt=prompt,
            max_tokens=1024,
            n=1,
            stop=None,
            temperature=0.5,
        )

        response = completion.choices[0].text
        response = completion.choices[0].text
        L1=response.split("||")
        question={}
        question["q"]= L1[0]
        question["choice1"] = L1[1]
        question["choice2"] = L1[2]
        question["choice3"] = L1[3]
        question["choice4"] = L1[4]
        answer=str(L1[5])
        answer=answer.replace("Answer:","")
        
        question["answer"] = int(answer)
            
        question["explanation"] = L1[6]
        return(question)



def PrintMenu():
   
        print("Select a category for your question : ")
        i = 1
        for c in  QuestionCategories:
            print(i,".",c["name"],flush=True)
            i+=1
        print("0. Exit",flush=True)    

        r=int(input("Enter your choice : "))
        return r
def main():
    
    choice=1
    while choice != 0:
        clear_output(wait=True)
        #sleep(1)
        choice=PrintMenu()
        if choice == 0:
            break
       
        topic= QuestionCategories[choice-1]["keyword"]
        print(topic, "Fetching question from ChatGPT...")
        question=GetQuestion(topic)
        clear_output(wait=True)
        print(question["q"],"\n")
        print(question["choice1"])
        print(question["choice2"])
        print(question["choice3"])
        print(question["choice4"])
        user_answer = int(input("Enter answer (1-4) :"))
        if user_answer == question["answer"]:
            print("Correct")
        else:
           print("Incorrect")
           print("Correct answer is",question["answer"]) 
        print(question["explanation"])    
        input("Press any key to continue")
        
        

    

main()
# Out:
# Select a category for your question :
# 1 . SQL
# 2 . Python output
# 0. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12484\2141468216.py in <module>
#      96
#      97
# ---> 98 main()
#      99
#
# ~\AppData\Local\Temp\ipykernel_12484\2141468216.py in main()
#      70         clear_output(wait=True)
#      71         #sleep(1)
# ---> 72         choice=PrintMenu()
#      73         if choice == 0:
#      74             break
#
# ~\AppData\Local\Temp\ipykernel_12484\2141468216.py in PrintMenu()
#      62         print("0. Exit",flush=True)
#      63
# ---> 64         r=int(input("Enter your choice : "))
#      65         return r
#      66 def main():
#
# d:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
# ...
